# %%
import pandas as pd
import json


def json_to_csv(file_descriptor, json_data):
    #for flight in json_data:
    flight = json_data
    w.write(
        str(flight['departure_date']).replace(',','') + ',' +
        str(flight['arrival_date']).replace(',','')+',' +
        str(flight['company']).replace(',','')+',' +
        str(flight['duration']).replace(',','')+',' +
        str(flight['stops']).replace(',','')+',' +
        str(flight['emissions']).replace(',','')+',' +
        str(flight['emission_comparison']).replace(',','')+',' +
        str(flight['price']).replace(',','')+',' +
        str(flight['price_type']).replace(',','')+',' +
        str(flight['departure_airport']).replace(',','')+',' +
        str(flight['arrival_airport']).replace(',','') + '\n'
    )

        
with open('outputs.txt', encoding='utf-8') as f:
    data = f.read()

blocks = data.split('}{')
for i in range(len(blocks)):
    if i == 0:
        blocks[i] = blocks[i] + '}'
    elif i == len(blocks) - 1:
        blocks[i] = '{' + blocks[i]
    else:
        blocks[i] = '{' + blocks[i] + '}'
    blocks[i] = blocks[i].replace(u"\u202f", "").replace(u"\n", "")

with open('outputs2.json', "w", encoding='utf-8') as w:
    for json_block in blocks:
        json_data = json.loads(json_block)
        try:
            for flight in json_data['best_departing_flights']:
                json_to_csv(w, flight)
            for flight in json_data['other_departing_flights']:
                json_to_csv(w, flight)
        except Exception as e:
            print('-------------------')
            print(e)
            print(json_data)
            print('-------------------')
        


    # data_frame = pd.read_json(part1)
    # csvBody = data_frame.to_csv()
    # print(csvBody)


# json_data = json.loads(blocks[0] + '}')
# print(json_data['best_departing_flights'])
# data_frame = pd.read_json(json_data['best_departing_flights'])
#data_frame['best_departing_flights'][0]
#csvBody = data_frame.to_csv()
#print(csvBody)
# data = json.loads(f.read())
# jsonBody = pd.json_normalize(data)
# csvBody = jsonBody.to_csv()
# Out:
# -------------------
# 'best_departing_flights'
# ...
